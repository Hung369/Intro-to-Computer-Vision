# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('albert-einstein_gray.jpg')

# %%
# kiểu dữ liệu của img
type(img)
# Out:
# numpy.ndarray

# %%
# kích thước img
img.shape
# Out:
# (949, 728)

# %%
# kiểu dữ liệu trong 1 pixel của img
img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
# mảng dữ liệu img
print(img)
# Out:
# [[85 85 85 ... 62 62 62]
#  [85 85 85 ... 64 65 64]
#  [85 85 85 ... 59 59 58]
#  ...
#  [36 42 42 ... 36 42 47]
#  [29 37 37 ... 36 43 44]
#  [33 40 37 ... 35 43 42]]

# %%
# truy cập 1 pixel bất kỳ
img[23][300]
# Out:
# 70

# %%
second = img.copy()
second
# Out:
# array([[85, 85, 85, ..., 62, 62, 62],
#        [85, 85, 85, ..., 64, 65, 64],
#        [85, 85, 85, ..., 59, 59, 58],
#        ...,
#        [36, 42, 42, ..., 36, 42, 47],
#        [29, 37, 37, ..., 36, 43, 44],
#        [33, 40, 37, ..., 35, 43, 42]], dtype=uint8)

# %%
# thay đổi giá trị tại 1 pixel và nhiều pixel
second[400, 400] = 255 # 1 pixel
second[330:430,300:400] = 250 # nhiều pixels
second[330:430,430:520] = 250
plt.imshow(second,cmap='gray')
